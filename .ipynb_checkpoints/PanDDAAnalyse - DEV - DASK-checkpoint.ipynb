# %%
# magics
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
# Regular Imports
import os, sys, configparser
import time

# %%
# Scientific imports
from joblib import Memory

import dask
from dask.distributed import Client, LocalCluster
from dask_jobqueue import SGECluster
# Out:
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/dask_jobqueue/config.py:12: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
# Dask functions
from functions import fit, get_reference_map, load_sample, evaluate_model, cluster_outliers, filter_clusters, estimate_bdcs, make_event_map, make_shell_maps, make_event_table
from pandda_analyse.criticise import make_map

# %%
# Multi Dataset Crystalography imports
import multi_dataset_crystalography as mdc # import MultiCrystalDataset
from multi_dataset_crystalography.utils import DefaultPanDDADataloader
from multi_dataset_crystalography.dataset.sample_loader import PanddaDiffractionDataTruncater

# %%
# PanDDA imports
from pandda_analyse.config import PanDDAConfig
from pandda_analyse.event_model import PanDDAEventModel
# from pandda_analyse.processor import ProcessModelSeriel
from pandda_analyse.event_model_distributed import PanDDAEventModelDistributed

# %% [markdown]
# # Args

# %%
# Arguments
arguments = None
# Config
config_path = "/dls/science/groups/i04-1/conor_dev/pandda/lib-python/pandda/pandda_analyse/pandda_analyse/analyse_config.ini"
config = configparser.ConfigParser()

# %% [markdown]
# # Config

# %%
config.read(config_path)
# Out:
# ['/dls/science/groups/i04-1/conor_dev/pandda/lib-python/pandda/pandda_analyse/pandda_analyse/analyse_config.ini']

# %%
pandda_config = PanDDAConfig(config)  # Maps options to code abstractions

# %% [markdown]
# # Memory

# %%
from joblib import Memory
memory = Memory("/dls/science/groups/i04-1/conor_dev/cache", verbose=0)

# %% [markdown]
# # Dataset

# %%
# %%time
# Get Dataset
pandda_dataset = mdc.dataset.dataset.MultiCrystalDataset(dataloader=pandda_config.dataloader,
                                         sample_loader=pandda_config.sample_loader
                                        )
# Out:
# CPU times: user 21.7 s, sys: 1.2 s, total: 22.9 s
# Wall time: 23.5 s

# %% [markdown]
# # Get reference Model

# %%
# %%time
# Get reference model
reference = pandda_config.get_reference(pandda_dataset.datasets)
pandda_dataset.sample_loader.reference = reference
# Out:
# CPU times: user 8.43 s, sys: 816 ms, total: 9.24 s
# Wall time: 9.51 s

# %% [markdown]
# # Apply transforms to dataset

# %%
# %%time
# Apply dataset transforms
if "data_check" in pandda_config.dataset_transforms:
    transform = pandda_config.dataset_transforms["data_check"]
    dataset = transform(pandda_dataset, reference)
    print("###### {} ######".format(transform.name))
    for block, record in transform.log().items():
        print("# # {} # #".format(block))
        print(record)
# Out:
# ###### PanddaDataChecker ######
# # # Rejected datasets # #
# Datasets rejected:
# PDK2-x0279: rejected - rmsd to reference
# PDK2-x0251: rejected - rmsd to reference
# PDK2-x0107: rejected - rmsd to reference
# PDK2-x0238: rejected - rmsd to reference
# PDK2-x0878: rejected - rmsd to reference
#
# CPU times: user 23.4 s, sys: 492 ms, total: 23.9 s
# Wall time: 24.2 s

# %%
# %%time
if "scale_diffraction" in pandda_config.dataset_transforms:
    transform = pandda_config.dataset_transforms["scale_diffraction"]
    dataset = memory.cache(transform)(dataset, reference)
    print("###### {} ######".format(transform.name))
    for block, record in transform.log().items():
        print("# # {} # #".format(block))
        print(record)
# Out:
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/ipykernel_launcher.py:3: JobLibCollisionWarning: Cannot detect name collisions for function 'unknown'
#   This is separate from the ipykernel package so we can avoid doing imports until
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/numpy/lib/function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# ###### PanddaDiffractionScaler ######
# # # Rejected datasets # #
# Datasets rejected:
# PDK2-x0641: rejected - scaling failed
# PDK2-x0318: rejected - scaling failed
# PDK2-x0317: rejected - scaling failed
#
# CPU times: user 4min 56s, sys: 1min 19s, total: 6min 15s
# Wall time: 6min 22s
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/ipykernel_launcher.py:3: UserWarning: Persisting input arguments took 25.14s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# %%time
if "filter_structure" in pandda_config.dataset_transforms:
    transform = pandda_config.dataset_transforms["filter_structure"]
    dataset = transform(dataset, reference)
    print("###### {} ######".format(transform.name))
    for block, record in transform.log().items():
        print("# # {} # #".format(block))
        print(record)
# Out:
# ###### PanddaDatasetFilterer ######
# # # Rejected datasets # #
# Datasets rejected:
# PDK2-x0281: rejected - non-identical structures
# PDK2-x0365: rejected - non-identical structures
# PDK2-x0658: rejected - non-identical structures
# PDK2-x0288: rejected - non-identical structures
# PDK2-x0182: rejected - non-identical structures
# PDK2-x0347: rejected - non-identical structures
# PDK2-x0676: rejected - non-identical structures
# PDK2-x0585: rejected - non-identical structures
# PDK2-x0248: rejected - non-identical structures
# PDK2-x0106: rejected - non-identical structures
# PDK2-x0287: rejected - non-identical structures
# PDK2-x0229: rejected - non-identical structures
# PDK2-x0289: rejected - non-identical structures
# PDK2-x0299: rejected - non-identical structures
# PDK2-x0310: rejected - non-identical structures
# PDK2-x0316: rejected - non-identical structures
# PDK2-x0192: rejected - non-identical structures
# PDK2-x0050: rejected - non-identical structures
# PDK2-x0236: rejected - non-identical structures
# PDK2-x0256: rejected - non-identical structures
# PDK2-x0859: rejected - non-identical structures
# PDK2-x0870: rejected - non-identical structures
# PDK2-x0696: rejected - non-identical structures
#
# CPU times: user 1.7 s, sys: 233 ms, total: 1.93 s
# Wall time: 1.91 s

# %%
# %%time
if "filter_wilson" in pandda_config.dataset_transforms:
    transform = pandda_config.dataset_transforms["filter_wilson"]
    dataset = transform(dataset, reference)
    print("###### {} ######".format(transform.name))
    for block, record in transform.log().items():
        print("# # {} # #".format(block))
        print(record)
# Out:
# /home/zoh22914/.local/lib/python2.7/site-packages/panddas-0.2.12-py2.7.egg/bamboo/stats/__init__.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   return 0.6745*devs/mdev
# ###### PanddaDatasetFiltererWilsonRMSD ######
# # # Rejected datasets # #
# Datasets rejected:
#
#
# CPU times: user 25.1 s, sys: 435 ms, total: 25.5 s
# Wall time: 25.5 s
# multi_dataset_crystalography/dataset/transforms.py:338: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   col='scaled_wilson_rmsd_all_z') > self.max_wilson_plot_z_score) or \
# multi_dataset_crystalography/dataset/transforms.py:340: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   col='scaled_wilson_rmsd_<4A_z') > self.max_wilson_plot_z_score) or \
# multi_dataset_crystalography/dataset/transforms.py:342: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   col='scaled_wilson_rmsd_>4A_z') > self.max_wilson_plot_z_score) or \
# multi_dataset_crystalography/dataset/transforms.py:344: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   col='scaled_wilson_ln_rmsd_z') > self.max_wilson_plot_z_score) or \
# multi_dataset_crystalography/dataset/transforms.py:346: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   col='scaled_wilson_ln_dev_z') > self.max_wilson_plot_z_score):

# %%
# %%time
if "align" in pandda_config.dataset_transforms:
    transform = pandda_config.dataset_transforms["align"]
    dataset = memory.cache(transform)(dataset, reference)
    print("###### {} ######".format(transform.name))
    for block, record in transform.log().items():
        print("# # {} # #".format(block))
        print(record)
# Out:
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/ipykernel_launcher.py:3: JobLibCollisionWarning: Cannot detect name collisions for function 'unknown'
#   This is separate from the ipykernel package so we can avoid doing imports until
# [Parallel(n_jobs=15)]: Using backend LokyBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done   1 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=15)]: Done   2 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=15)]: Done   3 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=15)]: Done   4 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=15)]: Done   5 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=15)]: Done   6 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=15)]: Done   7 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=15)]: Done   8 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=15)]: Done   9 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=15)]: Done  10 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=15)]: Done  11 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=15)]: Done  12 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=15)]: Done  13 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=15)]: Done  14 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=15)]: Done  15 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=15)]: Done  16 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=15)]: Done  17 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=15)]: Done  18 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=15)]: Done  19 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=15)]: Done  21 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=15)]: Done  22 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=15)]: Done  23 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=15)]: Done  24 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=15)]: Done  25 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=15)]: Done  26 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=15)]: Done  27 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=15)]: Done  28 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=15)]: Done  29 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=15)]: Done  30 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=15)]: Done  31 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=15)]: Done  32 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=15)]: Done  33 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=15)]: Done  34 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=15)]: Done  35 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=15)]: Done  36 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=15)]: Done  37 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=15)]: Done  38 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=15)]: Done  39 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=15)]: Done  40 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=15)]: Done  41 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=15)]: Done  42 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=15)]: Done  43 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=15)]: Done  44 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=15)]: Done  45 tasks      | elapsed:   43.1s
# [Parallel(n_jobs=15)]: Done  46 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=15)]: Done  47 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=15)]: Done  48 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=15)]: Done  49 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=15)]: Done  50 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=15)]: Done  51 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=15)]: Done  52 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=15)]: Done  53 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=15)]: Done  54 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=15)]: Done  55 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=15)]: Done  56 tasks      | elapsed:   43.9s
# [Parallel(n_jobs=15)]: Done  57 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=15)]: Done  58 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=15)]: Done  59 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=15)]: Done  60 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=15)]: Done  61 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=15)]: Done  62 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=15)]: Done  63 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=15)]: Done  64 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=15)]: Done  65 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=15)]: Done  66 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=15)]: Done  67 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=15)]: Done  68 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=15)]: Done  69 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=15)]: Done  70 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=15)]: Done  71 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=15)]: Done  72 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=15)]: Done  73 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=15)]: Done  74 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=15)]: Done  75 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=15)]: Done  76 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=15)]: Done  77 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=15)]: Done  78 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=15)]: Done  79 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=15)]: Done  80 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=15)]: Done  81 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=15)]: Done  82 tasks      | elapsed:   46.2s
# [Parallel(n_jobs=15)]: Done  83 tasks      | elapsed:   46.2s
# [Parallel(n_jobs=15)]: Done  84 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=15)]: Done  85 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=15)]: Done  86 tasks      | elapsed:   46.4s
# [Parallel(n_jobs=15)]: Done  87 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=15)]: Done  88 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=15)]: Done  89 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=15)]: Done  90 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=15)]: Done  91 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=15)]: Done  92 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=15)]: Done  93 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=15)]: Done  94 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=15)]: Done  95 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=15)]: Done  96 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=15)]: Done  97 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=15)]: Done  98 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=15)]: Done  99 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=15)]: Done 100 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=15)]: Done 101 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=15)]: Done 102 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=15)]: Done 103 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=15)]: Done 104 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=15)]: Done 105 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=15)]: Done 106 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=15)]: Done 107 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=15)]: Done 108 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=15)]: Done 109 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=15)]: Done 110 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=15)]: Done 111 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=15)]: Done 112 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=15)]: Done 113 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=15)]: Done 114 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=15)]: Done 115 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=15)]: Done 116 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=15)]: Done 117 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=15)]: Done 118 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=15)]: Done 119 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=15)]: Done 120 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=15)]: Done 121 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=15)]: Done 122 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=15)]: Done 123 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=15)]: Done 124 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=15)]: Done 125 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=15)]: Done 126 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=15)]: Done 127 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=15)]: Done 128 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=15)]: Done 129 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=15)]: Done 130 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=15)]: Done 131 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=15)]: Done 132 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=15)]: Done 133 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=15)]: Done 134 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=15)]: Done 135 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=15)]: Done 136 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=15)]: Done 137 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=15)]: Done 138 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=15)]: Done 139 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=15)]: Done 140 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=15)]: Done 141 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=15)]: Done 142 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=15)]: Done 143 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=15)]: Done 144 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=15)]: Done 145 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=15)]: Done 146 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=15)]: Done 147 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=15)]: Done 148 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=15)]: Done 149 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=15)]: Done 150 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=15)]: Done 151 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=15)]: Done 152 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=15)]: Done 153 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=15)]: Done 154 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=15)]: Done 155 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=15)]: Done 156 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=15)]: Done 157 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=15)]: Done 158 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=15)]: Done 159 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=15)]: Done 160 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=15)]: Done 161 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=15)]: Done 162 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=15)]: Done 163 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=15)]: Done 164 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=15)]: Done 165 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=15)]: Done 166 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=15)]: Done 167 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=15)]: Done 168 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=15)]: Done 169 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=15)]: Done 171 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=15)]: Done 172 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=15)]: Done 173 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=15)]: Done 174 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=15)]: Done 175 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=15)]: Done 176 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=15)]: Done 177 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=15)]: Done 178 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=15)]: Done 179 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=15)]: Done 180 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=15)]: Done 181 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=15)]: Done 182 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=15)]: Done 183 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=15)]: Done 184 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=15)]: Done 185 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=15)]: Done 186 tasks      | elapsed:   55.6s
# [Parallel(n_jobs=15)]: Done 187 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=15)]: Done 188 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=15)]: Done 189 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=15)]: Done 190 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=15)]: Done 191 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=15)]: Done 192 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=15)]: Done 193 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=15)]: Done 194 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=15)]: Done 195 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=15)]: Done 196 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=15)]: Done 197 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=15)]: Done 198 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=15)]: Done 199 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=15)]: Done 200 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=15)]: Done 201 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=15)]: Done 202 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=15)]: Done 203 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=15)]: Done 204 tasks      | elapsed:   57.1s
# [Parallel(n_jobs=15)]: Done 205 tasks      | elapsed:   57.1s
# [Parallel(n_jobs=15)]: Done 206 tasks      | elapsed:   57.1s
# [Parallel(n_jobs=15)]: Done 207 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=15)]: Done 208 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=15)]: Done 209 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=15)]: Done 210 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=15)]: Done 211 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=15)]: Done 212 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=15)]: Done 213 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=15)]: Done 214 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=15)]: Done 215 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=15)]: Done 216 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=15)]: Done 217 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=15)]: Done 218 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=15)]: Done 219 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=15)]: Done 220 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=15)]: Done 221 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=15)]: Done 222 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=15)]: Done 223 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=15)]: Done 224 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=15)]: Done 225 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=15)]: Done 226 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=15)]: Done 227 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=15)]: Done 228 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=15)]: Done 229 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=15)]: Done 230 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=15)]: Done 231 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=15)]: Done 232 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=15)]: Done 233 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=15)]: Done 234 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=15)]: Done 235 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=15)]: Done 236 tasks      | elapsed:   59.8s
# [Parallel(n_jobs=15)]: Done 237 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=15)]: Done 238 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=15)]: Done 239 tasks      | elapsed:   60.0s
# [Parallel(n_jobs=15)]: Done 240 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 241 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 242 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 243 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 244 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 245 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 246 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 247 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 248 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 249 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 250 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 251 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 252 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 253 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 254 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 255 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 256 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 257 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 258 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 259 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 260 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 261 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 262 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 263 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 264 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 265 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 266 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 267 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 268 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 269 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 270 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 271 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 272 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 273 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 274 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 275 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 276 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 277 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 278 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 279 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 280 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 281 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 282 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 283 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 284 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 285 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 286 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 287 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 288 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 289 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 290 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 291 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 292 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 293 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 294 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 295 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 296 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 297 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 298 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 299 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 300 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 301 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 302 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 303 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 304 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 305 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 306 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 307 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 308 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 309 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 310 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 311 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 312 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 313 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 314 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 315 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 316 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 317 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 318 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 319 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 320 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 321 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 322 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 323 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 324 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 325 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 326 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 327 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 328 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 329 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 330 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 331 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 332 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 333 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 334 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 335 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 336 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 337 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 338 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 339 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 340 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 341 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 342 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 343 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 344 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 345 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 346 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 347 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 348 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 349 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 350 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 351 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 352 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 353 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 354 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 355 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 356 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 357 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 358 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 359 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 360 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 361 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 362 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 363 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 364 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 365 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 366 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 367 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 368 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 369 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 370 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 371 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 372 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 373 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 374 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 375 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 376 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 377 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 378 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 379 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 380 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 381 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 382 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 383 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 384 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 385 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 386 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 387 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 388 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 389 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 390 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 391 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 392 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 393 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 394 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 395 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 396 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 397 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 398 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 399 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 400 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 401 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 402 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 403 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 404 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 405 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 406 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 407 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 408 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 409 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 410 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 411 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 412 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 413 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 414 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 415 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 416 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 417 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 418 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 419 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 420 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 421 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 422 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 423 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 424 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 425 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 426 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 427 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 428 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 429 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 430 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 431 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 432 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 433 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 435 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 436 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 437 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 438 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 439 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 440 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 441 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 442 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 443 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 444 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 445 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 446 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 447 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 448 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 449 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 450 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 451 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 452 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 453 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 454 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 455 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 456 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 457 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 458 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 459 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 460 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 461 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 462 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 463 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 464 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 465 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 466 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 467 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 468 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 469 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 470 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 471 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 472 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 473 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 474 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 475 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 476 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 477 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 478 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 479 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 480 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 481 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 482 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 483 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 484 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 485 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 486 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 487 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 488 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 489 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 490 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 491 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 492 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 493 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 494 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 495 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 496 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 497 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 498 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 499 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 500 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 501 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 502 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 503 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 504 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 505 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 506 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 507 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 508 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 509 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 510 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 511 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 512 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 513 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 514 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 515 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 516 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 517 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 518 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 519 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 520 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 521 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 522 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 523 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 524 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 525 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 526 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 527 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 528 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 529 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 530 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 531 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 532 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 533 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 534 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 535 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 536 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 537 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 538 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 539 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 540 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 541 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 542 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 543 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 544 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 545 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 546 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 547 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 548 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 549 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 550 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 551 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 552 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 553 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 554 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 555 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 556 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 557 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 558 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 559 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 560 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 561 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 562 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 563 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 564 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 565 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 566 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 567 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 568 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 569 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 570 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 571 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 572 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 573 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 574 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 575 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 576 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 577 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 578 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 579 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 580 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 581 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 582 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 583 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 584 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 585 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 586 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 587 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 588 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 589 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 590 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 591 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 592 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 593 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 594 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 595 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 596 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 597 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 598 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 599 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 600 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 601 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 602 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 603 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 604 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 605 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 606 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 607 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 608 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 609 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 610 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 611 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 612 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 613 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 614 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 615 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 616 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 617 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 618 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 619 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 620 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 621 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 622 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 623 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 624 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 625 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 626 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 627 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 628 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 629 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 630 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 631 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 632 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 633 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 634 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 635 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 636 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 637 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 638 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 639 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 640 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 641 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 642 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 643 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 644 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 645 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 646 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 647 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 648 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 649 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 650 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 651 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 652 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 653 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 654 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 655 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 656 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 657 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 658 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 659 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 660 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 661 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 662 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 663 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 664 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 665 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 666 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 667 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 668 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 669 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 670 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 671 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 672 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 673 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 674 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 675 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 676 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 677 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 678 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 679 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 680 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 681 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 682 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 683 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=15)]: Done 684 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 685 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 686 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 687 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 688 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 689 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 690 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 691 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 692 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 693 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 694 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 695 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 696 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 697 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 698 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 699 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 700 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 701 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 702 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 703 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 704 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 705 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 706 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 707 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 708 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 709 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 710 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 711 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 712 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 713 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 714 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 715 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 716 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 717 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 718 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 719 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 720 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 721 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 722 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 723 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 724 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 725 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 726 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 727 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 728 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 729 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 730 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 731 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 732 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 733 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 734 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 735 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 736 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 737 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 738 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 739 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 740 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 741 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=15)]: Done 770 out of 770 | elapsed:  1.8min finished
# ###### PanddaDefaultStructureAligner ######
# # # aligned_datasets # #
# Datasets aligned:
# PDK2-x0811
# PDK2-x0621
# PDK2-x0810
# PDK2-x0082
# PDK2-x0083
# PDK2-x0080
# PDK2-x0081
# PDK2-x0086
# PDK2-x0087
# PDK2-x0084
# PDK2-x0085
# PDK2-x0815
# PDK2-x0088
# PDK2-x0089
# PDK2-x0814
# PDK2-x0165
# PDK2-x0164
# PDK2-x0167
# PDK2-x0166
# PDK2-x0161
# PDK2-x0160
# PDK2-x0163
# PDK2-x0162
# PDK2-x0245
# PDK2-x0247
# PDK2-x0240
# PDK2-x0241
# PDK2-x0242
# PDK2-x0243
# PDK2-x0819
# PDK2-x0627
# PDK2-x0788
# PDK2-x0750
# PDK2-x0400
# PDK2-x0051
# PDK2-x0401
# PDK2-x0047
# PDK2-x0019
# PDK2-x0018
# PDK2-x0786
# PDK2-x0011
# PDK2-x0010
# PDK2-x0013
# PDK2-x0012
# PDK2-x0015
# PDK2-x0014
# PDK2-x0017
# PDK2-x0016
# PDK2-x0420
# PDK2-x0421
# PDK2-x0422
# PDK2-x0424
# PDK2-x0425
# PDK2-x0427
# PDK2-x0429
# PDK2-x0540
# PDK2-x0058
# PDK2-x0538
# PDK2-x0539
# PDK2-x0684
# PDK2-x0685
# PDK2-x0686
# PDK2-x0687
# PDK2-x0680
# PDK2-x0681
# PDK2-x0729
# PDK2-x0683
# PDK2-x0727
# PDK2-x0726
# PDK2-x0725
# PDK2-x0724
# PDK2-x0688
# PDK2-x0689
# PDK2-x0721
# PDK2-x0720
# PDK2-x0334
# PDK2-x0335
# PDK2-x0336
# PDK2-x0337
# PDK2-x0330
# PDK2-x0331
# PDK2-x0332
# PDK2-x0531
# PDK2-x0338
# PDK2-x0339
# PDK2-x0249
# PDK2-x0816
# PDK2-x0850
# PDK2-x0839
# PDK2-x0838
# PDK2-x0833
# PDK2-x0832
# PDK2-x0831
# PDK2-x0830
# PDK2-x0837
# PDK2-x0836
# PDK2-x0835
# PDK2-x0834
# PDK2-x0169
# PDK2-x0168
# PDK2-x0208
# PDK2-x0209
# PDK2-x0611
# PDK2-x0610
# PDK2-x0617
# PDK2-x0616
# PDK2-x0615
# PDK2-x0614
# PDK2-x0200
# PDK2-x0201
# PDK2-x0202
# PDK2-x0751
# PDK2-x0204
# PDK2-x0205
# PDK2-x0206
# PDK2-x0755
# PDK2-x0055
# PDK2-x0057
# PDK2-x0056
# PDK2-x0118
# PDK2-x0119
# PDK2-x0053
# PDK2-x0052
# PDK2-x0114
# PDK2-x0116
# PDK2-x0117
# PDK2-x0110
# PDK2-x0111
# PDK2-x0112
# PDK2-x0113
# PDK2-x0671
# PDK2-x0779
# PDK2-x0507
# PDK2-x0505
# PDK2-x0504
# PDK2-x0502
# PDK2-x0501
# PDK2-x0500
# PDK2-x0509
# PDK2-x0508
# PDK2-x0770
# PDK2-x0771
# PDK2-x0370
# PDK2-x0803
# PDK2-x0372
# PDK2-x0373
# PDK2-x0374
# PDK2-x0375
# PDK2-x0376
# PDK2-x0805
# PDK2-x0378
# PDK2-x0472
# PDK2-x0471
# PDK2-x0470
# PDK2-x0477
# PDK2-x0476
# PDK2-x0475
# PDK2-x0474
# PDK2-x0572
# PDK2-x0570
# PDK2-x0571
# PDK2-x0576
# PDK2-x0577
# PDK2-x0574
# PDK2-x0575
# PDK2-x0578
# PDK2-x0579
# PDK2-x0705
# PDK2-x0048
# PDK2-x0704
# PDK2-x0877
# PDK2-x0876
# PDK2-x0874
# PDK2-x0873
# PDK2-x0872
# PDK2-x0871
# PDK2-x0879
# PDK2-x0703
# PDK2-x0659
# PDK2-x0657
# PDK2-x0656
# PDK2-x0655
# PDK2-x0654
# PDK2-x0653
# PDK2-x0282
# PDK2-x0651
# PDK2-x0650
# PDK2-x0716
# PDK2-x0717
# PDK2-x0714
# PDK2-x0328
# PDK2-x0712
# PDK2-x0713
# PDK2-x0710
# PDK2-x0711
# PDK2-x0891
# PDK2-x0890
# PDK2-x0893
# PDK2-x0892
# PDK2-x0895
# PDK2-x0718
# PDK2-x0719
# PDK2-x0486
# PDK2-x0487
# PDK2-x0484
# PDK2-x0485
# PDK2-x0482
# PDK2-x0483
# PDK2-x0480
# PDK2-x0481
# PDK2-x0488
# PDK2-x0489
# PDK2-x0091
# PDK2-x0158
# PDK2-x0159
# PDK2-x0093
# PDK2-x0092
# PDK2-x0095
# PDK2-x0094
# PDK2-x0097
# PDK2-x0096
# PDK2-x0099
# PDK2-x0098
# PDK2-x0152
# PDK2-x0153
# PDK2-x0154
# PDK2-x0155
# PDK2-x0156
# PDK2-x0157
# PDK2-x0253
# PDK2-x0252
# PDK2-x0398
# PDK2-x0399
# PDK2-x0257
# PDK2-x0255
# PDK2-x0392
# PDK2-x0393
# PDK2-x0259
# PDK2-x0258
# PDK2-x0396
# PDK2-x0397
# PDK2-x0394
# PDK2-x0395
# PDK2-x0131
# PDK2-x0802
# PDK2-x0479
# PDK2-x0478
# PDK2-x0806
# PDK2-x0807
# PDK2-x0028
# PDK2-x0029
# PDK2-x0024
# PDK2-x0025
# PDK2-x0026
# PDK2-x0027
# PDK2-x0020
# PDK2-x0021
# PDK2-x0022
# PDK2-x0023
# PDK2-x0808
# PDK2-x0437
# PDK2-x0046
# PDK2-x0435
# PDK2-x0434
# PDK2-x0433
# PDK2-x0432
# PDK2-x0431
# PDK2-x0430
# PDK2-x0536
# PDK2-x0537
# PDK2-x0534
# PDK2-x0535
# PDK2-x0533
# PDK2-x0439
# PDK2-x0438
# PDK2-x0881
# PDK2-x0329
# PDK2-x0283
# PDK2-x0284
# PDK2-x0286
# PDK2-x0322
# PDK2-x0321
# PDK2-x0320
# PDK2-x0327
# PDK2-x0325
# PDK2-x0324
# PDK2-x0442
# PDK2-x0443
# PDK2-x0440
# PDK2-x0441
# PDK2-x0446
# PDK2-x0447
# PDK2-x0444
# PDK2-x0445
# PDK2-x0448
# PDK2-x0049
# PDK2-x0848
# PDK2-x0849
# PDK2-x0846
# PDK2-x0847
# PDK2-x0844
# PDK2-x0845
# PDK2-x0843
# PDK2-x0177
# PDK2-x0194
# PDK2-x0195
# PDK2-x0196
# PDK2-x0665
# PDK2-x0190
# PDK2-x0191
# PDK2-x0219
# PDK2-x0218
# PDK2-x0217
# PDK2-x0216
# PDK2-x0215
# PDK2-x0214
# PDK2-x0198
# PDK2-x0212
# PDK2-x0211
# PDK2-x0210
# PDK2-x0699
# PDK2-x0693
# PDK2-x0692
# PDK2-x0691
# PDK2-x0690
# PDK2-x0697
# PDK2-x0695
# PDK2-x0694
# PDK2-x0068
# PDK2-x0069
# PDK2-x0630
# PDK2-x0060
# PDK2-x0061
# PDK2-x0062
# PDK2-x0063
# PDK2-x0064
# PDK2-x0065
# PDK2-x0066
# PDK2-x0067
# PDK2-x0103
# PDK2-x0102
# PDK2-x0101
# PDK2-x0269
# PDK2-x0105
# PDK2-x0104
# PDK2-x0262
# PDK2-x0263
# PDK2-x0260
# PDK2-x0261
# PDK2-x0266
# PDK2-x0267
# PDK2-x0264
# PDK2-x0265
# PDK2-x0636
# PDK2-x0666
# PDK2-x0748
# PDK2-x0664
# PDK2-x0662
# PDK2-x0663
# PDK2-x0367
# PDK2-x0366
# PDK2-x0812
# PDK2-x0363
# PDK2-x0362
# PDK2-x0817
# PDK2-x0409
# PDK2-x0406
# PDK2-x0407
# PDK2-x0404
# PDK2-x0405
# PDK2-x0402
# PDK2-x0403
# PDK2-x0369
# PDK2-x0368
# PDK2-x0800
# PDK2-x0560
# PDK2-x0563
# PDK2-x0562
# PDK2-x0565
# PDK2-x0387
# PDK2-x0567
# PDK2-x0566
# PDK2-x0569
# PDK2-x0568
# PDK2-x0743
# PDK2-x0706
# PDK2-x0742
# PDK2-x0213
# PDK2-x0801
# PDK2-x0199
# PDK2-x0747
# PDK2-x0746
# PDK2-x0312
# PDK2-x0313
# PDK2-x0707
# PDK2-x0311
# PDK2-x0701
# PDK2-x0700
# PDK2-x0314
# PDK2-x0702
# PDK2-x0319
# PDK2-x0709
# PDK2-x0708
# PDK2-x0495
# PDK2-x0494
# PDK2-x0497
# PDK2-x0496
# PDK2-x0491
# PDK2-x0490
# PDK2-x0493
# PDK2-x0492
# PDK2-x0499
# PDK2-x0498
# PDK2-x0715
# PDK2-x0798
# PDK2-x0799
# PDK2-x0796
# PDK2-x0797
# PDK2-x0794
# PDK2-x0792
# PDK2-x0793
# PDK2-x0790
# PDK2-x0791
# PDK2-x0804
# PDK2-x0639
# PDK2-x0638
# PDK2-x0149
# PDK2-x0148
# PDK2-x0147
# PDK2-x0146
# PDK2-x0145
# PDK2-x0144
# PDK2-x0143
# PDK2-x0142
# PDK2-x0140
# PDK2-x0389
# PDK2-x0388
# PDK2-x0224
# PDK2-x0225
# PDK2-x0222
# PDK2-x0223
# PDK2-x0381
# PDK2-x0380
# PDK2-x0383
# PDK2-x0382
# PDK2-x0384
# PDK2-x0228
# PDK2-x0386
# PDK2-x0723
# PDK2-x0722
# PDK2-x0090
# PDK2-x0033
# PDK2-x0032
# PDK2-x0031
# PDK2-x0030
# PDK2-x0037
# PDK2-x0036
# PDK2-x0035
# PDK2-x0034
# PDK2-x0132
# PDK2-x0133
# PDK2-x0039
# PDK2-x0038
# PDK2-x0136
# PDK2-x0137
# PDK2-x0134
# PDK2-x0529
# PDK2-x0528
# PDK2-x0525
# PDK2-x0524
# PDK2-x0526
# PDK2-x0520
# PDK2-x0523
# PDK2-x0522
# PDK2-x0809
# PDK2-x0203
# PDK2-x0631
# PDK2-x0682
# PDK2-x0296
# PDK2-x0295
# PDK2-x0293
# PDK2-x0292
# PDK2-x0291
# PDK2-x0359
# PDK2-x0356
# PDK2-x0357
# PDK2-x0354
# PDK2-x0355
# PDK2-x0352
# PDK2-x0138
# PDK2-x0350
# PDK2-x0351
# PDK2-x0451
# PDK2-x0450
# PDK2-x0453
# PDK2-x0452
# PDK2-x0455
# PDK2-x0454
# PDK2-x0457
# PDK2-x0456
# PDK2-x0459
# PDK2-x0458
# PDK2-x0592
# PDK2-x0593
# PDK2-x0594
# PDK2-x0595
# PDK2-x0596
# PDK2-x0597
# PDK2-x0858
# PDK2-x0633
# PDK2-x0855
# PDK2-x0854
# PDK2-x0857
# PDK2-x0856
# PDK2-x0851
# PDK2-x0130
# PDK2-x0853
# PDK2-x0852
# PDK2-x0749
# PDK2-x0189
# PDK2-x0188
# PDK2-x0183
# PDK2-x0180
# PDK2-x0187
# PDK2-x0186
# PDK2-x0185
# PDK2-x0184
# PDK2-x0675
# PDK2-x0674
# PDK2-x0677
# PDK2-x0778
# PDK2-x0670
# PDK2-x0673
# PDK2-x0672
# PDK2-x0774
# PDK2-x0775
# PDK2-x0776
# PDK2-x0679
# PDK2-x0678
# PDK2-x0772
# PDK2-x0773
# PDK2-x0583
# PDK2-x0582
# PDK2-x0635
# PDK2-x0660
# PDK2-x0364
# PDK2-x0828
# PDK2-x0268
# PDK2-x0829
# PDK2-x0661
# PDK2-x0100
# PDK2-x0079
# PDK2-x0078
# PDK2-x0077
# PDK2-x0076
# PDK2-x0075
# PDK2-x0074
# PDK2-x0073
# PDK2-x0072
# PDK2-x0071
# PDK2-x0070
# PDK2-x0176
# PDK2-x0278
# PDK2-x0174
# PDK2-x0175
# PDK2-x0172
# PDK2-x0173
# PDK2-x0170
# PDK2-x0171
# PDK2-x0271
# PDK2-x0270
# PDK2-x0273
# PDK2-x0275
# PDK2-x0274
# PDK2-x0178
# PDK2-x0179
# PDK2-x0629
# PDK2-x0588
# PDK2-x0108
# PDK2-x0150
# PDK2-x0151
# PDK2-x0361
# PDK2-x0620
# PDK2-x0008
# PDK2-x0009
# PDK2-x0003
# PDK2-x0001
# PDK2-x0006
# PDK2-x0007
# PDK2-x0004
# PDK2-x0005
# PDK2-x0624
# PDK2-x0360
# PDK2-x0625
# PDK2-x0824
# PDK2-x0825
# PDK2-x0826
# PDK2-x0827
# PDK2-x0419
# PDK2-x0418
# PDK2-x0822
# PDK2-x0823
# PDK2-x0415
# PDK2-x0414
# PDK2-x0416
# PDK2-x0411
# PDK2-x0410
# PDK2-x0413
# PDK2-x0412
# PDK2-x0555
# PDK2-x0556
# PDK2-x0557
# PDK2-x0558
# PDK2-x0559
# PDK2-x0613
# PDK2-x0612
# PDK2-x0758
# PDK2-x0741
# PDK2-x0759
# PDK2-x0390
# PDK2-x0738
# PDK2-x0739
# PDK2-x0391
# PDK2-x0632
# PDK2-x0730
# PDK2-x0731
# PDK2-x0732
# PDK2-x0733
# PDK2-x0734
# PDK2-x0736
# PDK2-x0737
# PDK2-x0301
# PDK2-x0752
# PDK2-x0303
# PDK2-x0302
# PDK2-x0304
# PDK2-x0307
# PDK2-x0753
# PDK2-x0309
# PDK2-x0308
# PDK2-x0408
# PDK2-x0619
# PDK2-x0618
# PDK2-x0668
# PDK2-x0756
# PDK2-x0626
# PDK2-x0757
# PDK2-x0789
# PDK2-x0754
# PDK2-x0785
# PDK2-x0784
# PDK2-x0787
# PDK2-x0207
# PDK2-x0781
# PDK2-x0780
# PDK2-x0783
# PDK2-x0782
# PDK2-x0608
# PDK2-x0609
# PDK2-x0604
# PDK2-x0605
# PDK2-x0647
# PDK2-x0600
# PDK2-x0601
# PDK2-x0602
# PDK2-x0603
# PDK2-x0235
# PDK2-x0237
# PDK2-x0667
# PDK2-x0231
# PDK2-x0230
# PDK2-x0232
# PDK2-x0745
# PDK2-x0239
# PDK2-x0888
# PDK2-x0628
# PDK2-x0744
# PDK2-x0880
# PDK2-x0129
# PDK2-x0128
# PDK2-x0044
# PDK2-x0768
# PDK2-x0042
# PDK2-x0043
# PDK2-x0040
# PDK2-x0041
# PDK2-x0121
# PDK2-x0120
# PDK2-x0123
# PDK2-x0122
# PDK2-x0125
# PDK2-x0124
# PDK2-x0127
# PDK2-x0126
# PDK2-x0510
# PDK2-x0511
# PDK2-x0512
# PDK2-x0513
# PDK2-x0514
# PDK2-x0515
# PDK2-x0516
# PDK2-x0517
# PDK2-x0518
# PDK2-x0519
# PDK2-x0740
# PDK2-x0300
# PDK2-x0820
# PDK2-x0349
# PDK2-x0348
# PDK2-x0345
# PDK2-x0344
# PDK2-x0346
# PDK2-x0341
# PDK2-x0340
# PDK2-x0821
# PDK2-x0342
# PDK2-x0464
# PDK2-x0465
# PDK2-x0466
# PDK2-x0467
# PDK2-x0460
# PDK2-x0461
# PDK2-x0463
# PDK2-x0587
# PDK2-x0586
# PDK2-x0584
# PDK2-x0468
# PDK2-x0469
# PDK2-x0581
# PDK2-x0580
# PDK2-x0728
# PDK2-x0358
# PDK2-x0622
# PDK2-x0860
# PDK2-x0861
# PDK2-x0862
# PDK2-x0863
# PDK2-x0864
# PDK2-x0865
# PDK2-x0866
# PDK2-x0867
# PDK2-x0868
# PDK2-x0869
# PDK2-x0648
# PDK2-x0649
# PDK2-x0590
# PDK2-x0623
# PDK2-x0642
# PDK2-x0643
# PDK2-x0644
# PDK2-x0645
# PDK2-x0646
# PDK2-x0353
# PDK2-x0763
# PDK2-x0762
# PDK2-x0761
# PDK2-x0760
# PDK2-x0767
# PDK2-x0766
# PDK2-x0765
# PDK2-x0764
# PDK2-x0882
# PDK2-x0883
# PDK2-x0769
# PDK2-x0298
# PDK2-x0886
# PDK2-x0885
# PDK2-x0598
# PDK2-x0599
# PDK2-x0193
#
# # # not_aligned_datasets # #
# Datasets not aligned:
#
#
# CPU times: user 9min 2s, sys: 24.9 s, total: 9min 27s
# Wall time: 10min 33s
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/ipykernel_launcher.py:3: UserWarning: Persisting input arguments took 85.17s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Get Grid

# %%
# %%time
grid = dataset.sample_loader.get_grid(reference)
# Out:
# ----------------------------------->>>
# Atomic Mask Summary:
# Total Mask Size (1D): 823828
# Outer Mask Size (1D): 905167
# Inner Mask Size (1D): 81339
# Masked Grid Min/Max: ((7, 69, 108), (144, 52, 62))
# ----------------------------------->>>
# Atomic Mask Summary:
# Total Mask Size (1D): 800827
# Outer Mask Size (1D): 2072287
# Inner Mask Size (1D): 1271460
# Masked Grid Min/Max: ((0, 0, 1), (151, 133, 160))
# CPU times: user 33.2 s, sys: 2.4 s, total: 35.6 s
# Wall time: 47.1 s

# %% [markdown]
# # Setup Output

# %%
# %%time
tree = pandda_config.pandda_output(dataset)
for block, record in pandda_config.pandda_output.log().items():
    print("####### {} ########".format(block))
    print(record)
# Out:
# ####### pandda_created ########
# Output directory created:
# True
#
# CPU times: user 3.21 s, sys: 2.78 s, total: 5.99 s
# Wall time: 35.7 s

# %% [markdown]
# # Model

# %%
# %%time
# Define Model
pandda_event_model = PanDDAEventModel(pandda_config.statistical_model,
                                      pandda_config.clusterer,
                                      pandda_config.event_finder,
                                      bdc_calculator=pandda_config.bdc_calculator,
                                      statistics=[],
                                      map_maker=pandda_config.map_maker, 
                                      event_table_maker=pandda_config.event_table_maker,
                                      cpus=config["args"]["cpus"],
                                      tree=tree)
# Out:
# CPU times: user 184 µs, sys: 22 µs, total: 206 µs
# Wall time: 202 µs

# %% [markdown]
# # Partition

# %%
# %%time
dataset.partitions = pandda_config.partitioner(dataset.datasets)
# Out:
# CPU times: user 704 µs, sys: 0 ns, total: 704 µs
# Wall time: 587 µs

# %% [markdown]
# # Dask Functions

# %%
statistical_model = pandda_config.statistical_model
sample_loader = pandda_config.sample_loader

clusterer = pandda_config.clusterer
event_finder = pandda_config.event_finder
bdc_calculator = pandda_config.bdc_calculator

criticiser = pandda_config.criticiser
criticiser_all = pandda_config.criticiser_all

# %% [markdown]
# # Fi, evaluate, criticise - single dataset

# %%
dask.config.config
dask.config.set({"distributed.admin.tick.limit": "300s"})

# %%
cluster = SGECluster(queue="medium.q",
                     project="labxchem",
                     cores=10,
                     processes=5,
                           memory="64GB",
                           resource_spec="m_mem_free=64G,redhat_release=rhel7",
                    python="/dls/science/groups/i04-1/conor_dev/ccp4/build/bin/cctbx.python",
                    walltime="03:00:00")
cluster.scale(60)
# Out:
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/distributed/deploy/local.py:138: UserWarning: diagnostics_port has been deprecated. Please use `dashboard_address=` instead
#   "diagnostics_port has been deprecated. "

# %%
# client.close()

# %%
# del cluster
# del client

# %%
# cluster = LocalCluster(n_workers=5, 
#                       memory_limit="25GB"
#                       )

# %%
# client = Client(n_workers=1)

# %%
time.sleep(30)

# %%
client = Client(cluster)

# %%
# cluster.close()

# %%
# client.restart()

# %%
# time.sleep(15)

# %%
client
# Out:
# <Client: scheduler='tcp://172.23.159.7:35352' processes=60 cores=120>

# %%
# client.close()

# %%
# client.restart()

# %%
# print(dir(client))
# workers = client.scheduler.workers_to_close(n=8)
# client.scheduler.retire_workers(workers=workers,close_workers=True,remove=True)

# %%
# cluster.restart()
# client.restart()

# %%
# cluster.scale(8)

# %%
# cluster.close()

# %%
# Main Loop
dataloader = DefaultPanDDADataloader(min_train_datasets=60, 
                                     max_test_datasets=60)

# %%
ds = [(idx, d) for idx, d in dataloader(dataset)]
# Out:
# Got all train datasets
# Sorted datasets
# Collected trian datasets
# Got all test datasets
# sorted test datasets
# yielding dataset
# Dataset 0 of length 60; res limits (2.13786674777,2.13786674777)
# yielding dataset
# Dataset 1 of length 111; res limits (2.13849713107,2.23009496576)
# yielding dataset
# Dataset 2 of length 120; res limits (2.23981287927,2.31509360885)
# yielding dataset
# Dataset 3 of length 120; res limits (2.31816393209,2.3755079232)
# yielding dataset
# Dataset 4 of length 120; res limits (2.37600830711,2.45904047421)
# yielding dataset
# Dataset 5 of length 120; res limits (2.45982275972,2.5285230784)
# yielding dataset
# Dataset 6 of length 120; res limits (2.5290507321,2.58989421755)
# yielding dataset
# Dataset 7 of length 120; res limits (2.59023952047,2.64984944033)
# yielding dataset
# Dataset 8 of length 120; res limits (2.64990070685,2.71924167548)
# yielding dataset
# Dataset 9 of length 120; res limits (2.71972848577,2.78869368508)
# yielding dataset
# Dataset 10 of length 117; res limits (2.78887056265,2.87976295241)
# yielding dataset
# Dataset 11 of length 91; res limits (2.88901749955,2.98010309037)
# yielding dataset
# Dataset 12 of length 90; res limits (2.98955575049,3.08028773858)
# yielding dataset
# Dataset 13 of length 79; res limits (3.09027284951,3.1891636924)
# yielding dataset
# Dataset 14 of length 82; res limits (3.1997746183,3.29073119246)
# yielding dataset
# Dataset 15 of length 66; res limits (3.30096543159,3.38923478332)
# yielding dataset
# Dataset 16 of length 70; res limits (3.41049048277,3.50056559547)
# yielding dataset
# Dataset 17 of length 61; res limits (3.76983984191,3.76983984191)

# %% [markdown]
# # Define Task graph

# %%
# dsk = {}

# %% [markdown]
# # Define Functions

# %%
# # Sample Loader
# dsk["sample_loader"] = dataset.sample_loader
# dsk["reference_map_getter"] = pandda_config.reference_map_getter
# dsk["map_loader"] = pandda_config.map_loader

# # Statistical Model
# dsk["statistical_model"] = pandda_config.statistical_model

# # Event Finding
# # # Clusterer
# dsk["clusterer"] = pandda_config.clusterer
# # # event finder
# dsk["event_finder"] = pandda_config.event_finder
# # # bdc clus
# dsk["bdc_calculator"] = pandda_config.bdc_calculator

# # Criticism
# # # Map maker
# dsk["map_maker"] = pandda_config.map_maker
# # # Event table maker
# dsk["event_table_maker"] = pandda_config.event_table_maker

# %% [markdown]
# # Define Data

# %% [markdown]
# ### Global Data

# %%
# # Tree
# dsk["tree"] = tree

# # Reference
# dsk["reference"] = reference

# # Grid object
# # Doesn't work because of multiprocessing inside grid getting!
# # dsk["grid"] = (lambda sl, ref: sl.get_grid(reference=ref),
# #                   "sample_loader",
# #                   "reference")
# dsk["grid"] = grid

# %%
class TruncatedDatasets:
    def __init__(self, truncated_datasets):
        self.datasets = truncated_datasets
        
    def get_dataset(self, name):
        return self.datasets[name]

# %% [markdown]
# ### Shell Data

# %%
# %%time
from dask import delayed

 
name = ds[0][0]
d = ds[0][1]
print(d)

# ###############################################
# Get resolution
# ###############################################
resolutions_test = max([dts.data.summary.high_res for dtag, dts
                            in d.partition_datasets("test").items()])
resolutions_train = max([dts.data.summary.high_res for dtag, dts
                             in d.partition_datasets("train").items()])
max_res = max(resolutions_test, resolutions_train)


# ###############################################
# Instantiate sheel variable names
# ###############################################

# Dataset names
dtags = set(d.partition_datasets("test").keys()
                + d.partition_datasets("train").keys()
                )

dask_dtags = {"{}".format(dtag.replace("-", "_")): dtag
             for dtag
             in dtags}
train_dtags = [dtag 
               for dtag 
               in dask_dtags
               if (dask_dtags[dtag] in d.partition_datasets("train").keys())]
test_dtags = [dtag 
                   for dtag 
                   in dask_dtags
                   if (dask_dtags[dtag] in d.partition_datasets("test").keys())]   


# ###############################################
# Truncate datasets
# ###############################################
# TODO: move to imports section

truncated_reference, truncated_datasets = PanddaDiffractionDataTruncater()(d.datasets,
                                                                           reference)

# ###############################################
# Load computed variables into dask
# ###############################################
# Load shell sample laoder
shell_sample_loader = sample_loader.instantiate(grid, reference)

# Add truncated reference
shell_reference = truncated_reference

# Rename trucnated datasets
for ddtag, dtag in dask_dtags.items():
    truncated_datasets[ddtag] = truncated_datasets[dtag]

# record max res of shell datasets
shell_max_res = max_res
# Out:
# <multi_dataset_crystalography.dataset.dataset.MultiCrystalDataset instance at 0x7f1ceab633f8>
# CPU times: user 1.28 s, sys: 71.1 ms, total: 1.35 s
# Wall time: 1.36 s

# %%
# ###############################################
# Generate maps
# ###############################################

# Generate reference map for shell
shell_ref_map = delayed(get_reference_map)(pandda_config.reference_map_getter, 
                                           reference, 
                                           shell_max_res, 
                                           grid)

# Load maps
xmaps = {}
for dtag in dask_dtags:
    xmaps[dtag] = delayed(load_sample)(pandda_config.map_loader, 
                                       truncated_datasets[dtag],
                                       grid,
                                       shell_ref_map,
                                       shell_max_res)

# ###############################################
# Fit statistical model to trianing sets
# ###############################################

# %%
def identity(x):
    return x

def get_persisted(x):
    return dask.delayed(identity)(x).compute()

# %%
# %%time
# xmaps_delayed = dask.delayed(dict)([(dtag, xmaps_loaded[dtag]) for dtag in dask_dtags])
# xmaps_persisted_future = client.persist(xmaps_delayed)
xmaps_persisted_futures = client.persist([xmaps[dtag] for dtag in dask_dtags])
# Out:
# /dls/science/groups/i04-1/conor_dev/ccp4/base/lib/python2.7/site-packages/distributed/worker.py:3101: UserWarning: Large object of size 84.22 MB detected in task graph:
#   (<multi_dataset_crystalography.dataset.sample_load ... 37866747767121)
# Consider scattering large objects ahead of time
# with client.scatter to reduce scheduler burden and
# keep data on workers
#
#     future = client.submit(func, big_data)    # bad
#
#     big_future = client.scatter(big_data)     # good
#     future = client.submit(func, big_future)  # good
#   % (format_bytes(len(b)), s)
# CPU times: user 1min 44s, sys: 7.68 s, total: 1min 51s
# Wall time: 1min 52s

# %%
# client.compute(xmaps_persisted_futures[0]).result()
# Out:
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.23.159.7:42762 remote=tcp://172.23.159.7:35352>

# %%
# xmaps_computed = get_persisted(xmaps_persisted)

# %%
# xmaps_futures_dict = {dtag: xmaps_persisted_futures[i] for i, dtag in enumerate(dask_dtags)}
# xmaps_futures_dict

# %%
# %%time
# xmaps_computed = [client.compute(xmaps_futures_dict[dtag]).result() for dtag in dask_dtags]
xmaps_computed = {dtag: client.compute(xmaps_persisted_futures[i]).result() 
                  for i, dtag 
                  in enumerate(dask_dtags)}
# Out:
# CPU times: user 57.8 s, sys: 22 s, total: 1min 19s
# Wall time: 3min 35s

# %%
# %%time

shell_fit_model = fit(pandda_config.statistical_model, 
                                         [xmaps_computed[dtag] for dtag in train_dtags], 
                                         [xmaps_computed[dtag] for dtag in test_dtags]
                                        )
# Out:
# 	### Fitting mu!
# >> 100 % [==================================================]
# 	### Fitting sigma_uncertainty!
# 1   5    10   15   20   25   30   35   40   45   50   55   60
# |                                                           |
# 	### Fitting sigma_adjusted!
# >> 100 % [==================================================]
# CPU times: user 1min 30s, sys: 10.6 s, total: 1min 40s
# Wall time: 2min 4s

# %%
# %%time
shell_fit_model_scattered = client.scatter(shell_fit_model)
# Out:
# CPU times: user 748 ms, sys: 313 ms, total: 1.06 s
# Wall time: 3.01 s

# %%
# %%time
xmaps_scattered = client.scatter([xmaps_computed[dtag] for dtag in dask_dtags])
# Out:
# CPU times: user 5.71 s, sys: 2.01 s, total: 7.72 s
# Wall time: 12.2 s

# %%
xmaps_scattered_dict = {dtag: xmaps_scattered[i] for i, dtag in enumerate(dask_dtags)}

# %%
grid_scattered = client.scatter(grid)

# %%
# %%time
# ###############################################
# Find events
# ###############################################
zmaps = {}
clusters = {}
events = {}
bdcs = {}
for dtag in dask_dtags:
    # Get z maps by evaluating model on maps
    zmaps[dtag]  = delayed(evaluate_model)(shell_fit_model,
                                               xmaps_scattered_dict[dtag]
                                              )

    # Cluster outlying points in z maps
    clusters[dtag]  = delayed(cluster_outliers)(pandda_config.clusterer,
                                                truncated_datasets[dtag],
                                                zmaps[dtag],
                                                grid_scattered
                                              )


    # Find events by filtering the clusters
    events[dtag]  = delayed(filter_clusters)(pandda_config.event_finder,
                                               truncated_datasets[dtag],
                                             clusters[dtag],
                                               grid_scattered
                                              )
# Out:
# CPU times: user 19.8 ms, sys: 6.9 ms, total: 26.7 ms
# Wall time: 22.2 ms

# %%
# events_delayed = dask.delayed(dict)([(dtag, events[dtag]) for dtag in dask_dtags])
# cluster_outliers(pandda_config.clusterer, truncated_datasets['PDK2_x0008'], x['PDK2_x0008'], grid)

# %%
# zmaps_delayed = dask.delayed(dict)([(dtag, zmaps[dtag]) for dtag in dask_dtags])

# %%
# x = zmaps_delayed.compute()

# %%
# x

# %%
# clusters_delayed = dask.delayed(dict)([(dtag, clusters[dtag]) for dtag in dask_dtags])

# %%
# y = clusters_delayed.compute()

# %%
# y
# right(article(widget(email)))
# right(email) | content | widget
# right(email) | content | (ask() | )
# view.run(email)
# view: return page | div
# page: return content | div
# ask() | greet : reader(str->str)
# greet: str -> reader
#

# %%
# %%time
events_persisted_futures = client.persist([events[dtag] for dtag in dask_dtags])
# Out:
# CPU times: user 24.7 s, sys: 6.05 s, total: 30.7 s
# Wall time: 30.8 s

# %%
# events_persisted_futures

# %%
# %%time
events_computed = {dtag: client.compute(events_persisted_futures[i]).result() 
                  for i, dtag 
                  in enumerate(dask_dtags)}
# Out:
# CPU times: user 43.6 s, sys: 17.3 s, total: 1min
# Wall time: 3min 41s

# %%
events_scattered = client.scatter([events_computed[dtag] for dtag in dask_dtags])
events_scattered_dict = {dtag: xmaps_scattered[i] for i, dtag in enumerate(dask_dtags)}

# %%
# Calculate background correction factors
for dtag in dask_dtags:

    bdcs[dtag]  = delayed(estimate_bdcs)(pandda_config.bdc_calculator,
                                         truncated_datasets[dtag],
                                         xmaps_scattered_dict[dtag],
                                         shell_ref_map,
                                         events[dtag],
                                         grid_scattered
                                              )

# %%
# %%time
bdcs_persisted_futures = client.persist([bdcs[dtag] for dtag in dask_dtags])
# Out:
# CPU times: user 30.2 s, sys: 7.1 s, total: 37.3 s
# Wall time: 37.3 s

# %%
# %%time
bdcs_computed = {dtag: client.compute(bdcs_persisted_futures[i]).result() 
                  for i, dtag 
                  in enumerate(dask_dtags)}
# Out:
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.23.159.7:43146 remote=tcp://172.23.159.7:35352>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.23.159.7:43148 remote=tcp://172.23.159.7:35352>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.23.159.7:43150 remote=tcp://172.23.159.7:35352>
# CPU times: user 16.4 s, sys: 11 s, total: 27.4 s
# Wall time: 52 s

# %%
bdcs_computed
# Out:
# {'PDK2_x0008': OrderedDict(),
#  'PDK2_x0012': OrderedDict(),
#  'PDK2_x0021': OrderedDict(),
#  'PDK2_x0033': OrderedDict(),
#  'PDK2_x0071': OrderedDict([(('PDK2-x0071', 1), 0.87),
#               (('PDK2-x0071', 2), 0.84)]),
#  'PDK2_x0081': OrderedDict(),
#  'PDK2_x0087': OrderedDict([(('PDK2-x0087', 1), 0.84)]),
#  'PDK2_x0100': OrderedDict(),
#  'PDK2_x0138': OrderedDict([(('PDK2-x0138', 1), 0.88),
#               (('PDK2-x0138', 2), 0.88)]),
#  'PDK2_x0173': OrderedDict(),
#  'PDK2_x0187': OrderedDict([(('PDK2-x0187', 1), 0.78),
#               (('PDK2-x0187', 2), 0.84)]),
#  'PDK2_x0190': OrderedDict([(('PDK2-x0190', 1), 0.83)]),
#  'PDK2_x0214': OrderedDict([(('PDK2-x0214', 1), 0.88)]),
#  'PDK2_x0219': OrderedDict(),
#  'PDK2_x0275': OrderedDict(),
#  'PDK2_x0329': OrderedDict([(('PDK2-x0329', 1), 0.9299999999999999),
#               (('PDK2-x0329', 2), 0.86)]),
#  'PDK2_x0352': OrderedDict([(('PDK2-x0352', 1), 0.83)]),
#  'PDK2_x0383': OrderedDict([(('PDK2-x0383', 1), 0.84),
#               (('PDK2-x0383', 2), 0.75)]),
#  'PDK2_x0384': OrderedDict(),
#  'PDK2_x0386': OrderedDict(),
#  'PDK2_x0387': OrderedDict(),
#  'PDK2_x0395': OrderedDict([(('PDK2-x0395', 1), 0.8)]),
#  'PDK2_x0407': OrderedDict(),
#  'PDK2_x0422': OrderedDict([(('PDK2-x0422', 1), 0.85),
#               (('PDK2-x0422', 2), 0.8200000000000001)]),
#  'PDK2_x0446': OrderedDict([(('PDK2-x0446', 1), 0.84)]),
#  'PDK2_x0492': OrderedDict([(('PDK2-x0492', 1), 0.78)]),
#  'PDK2_x0510': OrderedDict(),
#  'PDK2_x0513': OrderedDict(),
#  'PDK2_x0516': OrderedDict([(('PDK2-x0516', 1), 0.87)]),
#  'PDK2_x0517': OrderedDict([(('PDK2-x0517', 1), 0.88)]),
#  'PDK2_x0522': OrderedDict([(('PDK2-x0522', 1), 0.8)]),
#  'PDK2_x0526': OrderedDict([(('PDK2-x0526', 1), 0.78),
#               (('PDK2-x0526', 2), 0.81),
#               (('PDK2-x0526', 3), 0.79),
#               (('PDK2-x0526', 4), 0.89)]),
#  'PDK2_x0537': OrderedDict(),
#  'PDK2_x0555': OrderedDict([(('PDK2-x0555', 1), 0.7),
#               (('PDK2-x0555', 2), 0.6699999999999999),
#               (('PDK2-x0555', 3), 0.71)]),
#  'PDK2_x0574': OrderedDict(),
#  'PDK2_x0620': OrderedDict(),
#  'PDK2_x0621': OrderedDict([(('PDK2-x0621', 1), 0.83),
#               (('PDK2-x0621', 2), 0.89)]),
#  'PDK2_x0644': OrderedDict(),
#  'PDK2_x0645': OrderedDict(),
#  'PDK2_x0695': OrderedDict([(('PDK2-x0695', 1), 0.86),
#               (('PDK2-x0695', 2), 0.92),
#               (('PDK2-x0695', 3), 0.91),
#               (('PDK2-x0695', 4), 0.92)]),
#  'PDK2_x0710': OrderedDict([(('PDK2-x0710', 1), 0.8),
#               (('PDK2-x0710', 2), 0.88),
#               (('PDK2-x0710', 3), 0.79),
#               (('PDK2-x0710', 4), 0.71),
#               (('PDK2-x0710', 5), 0.85),
#               (('PDK2-x0710', 6), 0.87),
#               (('PDK2-x0710', 7), 0.79),
#               (('PDK2-x0710', 8), 0.79),
#               (('PDK2-x0710', 9), 0.8),
#               (('PDK2-x0710', 10), 0.85),
#               (('PDK2-x0710', 11), 0.72),
#               (('PDK2-x0710', 12), 0.77),
#               (('PDK2-x0710', 13), 0.85)]),
#  'PDK2_x0712': OrderedDict(),
#  'PDK2_x0736': OrderedDict(),
#  'PDK2_x0739': OrderedDict(),
#  'PDK2_x0760': OrderedDict(),
#  'PDK2_x0802': OrderedDict([(('PDK2-x0802', 1), 0.85),
#               (('PDK2-x0802', 2), 0.88)]),
#  'PDK2_x0808': OrderedDict(),
#  'PDK2_x0812': OrderedDict([(('PDK2-x0812', 1), 0.78),
#               (('PDK2-x0812', 2), 0.69),
#               (('PDK2-x0812', 3), 0.72)]),
#  'PDK2_x0815': OrderedDict(),
#  'PDK2_x0817': OrderedDict([(('PDK2-x0817', 1), 0.79),
#               (('PDK2-x0817', 2), 0.79)]),
#  'PDK2_x0819': OrderedDict(),
#  'PDK2_x0828': OrderedDict(),
#  'PDK2_x0832': OrderedDict(),
#  'PDK2_x0839': OrderedDict(),
#  'PDK2_x0848': OrderedDict(),
#  'PDK2_x0849': OrderedDict(),
#  'PDK2_x0861': OrderedDict(),
#  'PDK2_x0865': OrderedDict(),
#  'PDK2_x0883': OrderedDict(),
#  'PDK2_x0891': OrderedDict()}

# %%
events_computed
# Out:
# {'PDK2_x0008': (0, [], []),
#  'PDK2_x0012': (0, [], []),
#  'PDK2_x0021': (0, [], []),
#  'PDK2_x0033': (0, [], []),
#  'PDK2_x0071': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8722aa0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce87223c0>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8722730>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8722788>)],
#   [<pandda.analyse.events.Event at 0x7f1cf4fb0790>,
#    <pandda.analyse.events.Event at 0x7f1cf0af8490>]),
#  'PDK2_x0081': (0, [], []),
#  'PDK2_x0087': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf82f1b50>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf82f1aa0>)],
#   [<pandda.analyse.events.Event at 0x7f1cf5defc10>]),
#  'PDK2_x0100': (0, [], []),
#  'PDK2_x0138': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf9286cb0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf9286208>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf9788998>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871caa0>)],
#   [<pandda.analyse.events.Event at 0x7f1cf0ae6150>,
#    <pandda.analyse.events.Event at 0x7f1cea02cb50>]),
#  'PDK2_x0173': (0, [], []),
#  'PDK2_x0187': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf4035158>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf5186260>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf82f18e8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf82f15d0>)],
#   [<pandda.analyse.events.Event at 0x7f1ce91efb90>,
#    <pandda.analyse.events.Event at 0x7f1cf3af8b50>]),
#  'PDK2_x0190': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf5453578>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce87055d0>)],
#   [<pandda.analyse.events.Event at 0x7f1cf28db510>]),
#  'PDK2_x0214': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf82fe8e8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf82fe050>)],
#   [<pandda.analyse.events.Event at 0x7f1cf3ad3210>]),
#  'PDK2_x0219': (0, [], []),
#  'PDK2_x0275': (0, [], []),
#  'PDK2_x0329': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf97b2e68>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf9286260>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf97887e0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c890>)],
#   [<pandda.analyse.events.Event at 0x7f1cf0ac4250>,
#    <pandda.analyse.events.Event at 0x7f1cf0ac4a50>]),
#  'PDK2_x0352': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf92869f0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf5453368>)],
#   [<pandda.analyse.events.Event at 0x7f1cf0af88d0>]),
#  'PDK2_x0383': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8722f70>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8722578>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce87227e0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8722cb0>)],
#   [<pandda.analyse.events.Event at 0x7f1cf2d92ad0>,
#    <pandda.analyse.events.Event at 0x7f1cf82788d0>]),
#  'PDK2_x0384': (0, [], []),
#  'PDK2_x0386': (0, [], []),
#  'PDK2_x0387': (0, [], []),
#  'PDK2_x0395': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf9286e10>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf9286310>)],
#   [<pandda.analyse.events.Event at 0x7f1cea026210>]),
#  'PDK2_x0407': (0, [], []),
#  'PDK2_x0422': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8eb9260>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8ead6d8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf36e5940>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf36e56d8>)],
#   [<pandda.analyse.events.Event at 0x7f1cf1c15350>,
#    <pandda.analyse.events.Event at 0x7f1ce91ef1d0>]),
#  'PDK2_x0446': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf4035e68>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8e8d998>)],
#   [<pandda.analyse.events.Event at 0x7f1cf4aea4d0>]),
#  'PDK2_x0492': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871cb50>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705310>)],
#   [<pandda.analyse.events.Event at 0x7f1cf16f7e90>]),
#  'PDK2_x0510': (0, [], []),
#  'PDK2_x0513': (0, [], []),
#  'PDK2_x0516': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf82f1d08>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf97b2d08>)],
#   [<pandda.analyse.events.Event at 0x7f1cf0adc250>]),
#  'PDK2_x0517': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf178f368>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf178fdb8>)],
#   [<pandda.analyse.events.Event at 0x7f1cf3c87d10>]),
#  'PDK2_x0522': (1,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf92867e0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871cf70>)],
#   [<pandda.analyse.events.Event at 0x7f1cf48fb5d0>]),
#  'PDK2_x0526': (4,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705470>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c940>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce87225d0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8722628>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8722310>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce87226d8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8722838>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8722260>)],
#   [<pandda.analyse.events.Event at 0x7f1cf421b650>,
#    <pandda.analyse.events.Event at 0x7f1cf0ac4c10>,
#    <pandda.analyse.events.Event at 0x7f1cf0ac4d50>,
#    <pandda.analyse.events.Event at 0x7f1cea29d610>]),
#  'PDK2_x0537': (0, [], []),
#  'PDK2_x0555': (3,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf9286c00>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf0f1f158>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf178f788>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf178f6d8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce9a32578>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf9788a48>)],
#   [<pandda.analyse.events.Event at 0x7f1ce9ccb4d0>,
#    <pandda.analyse.events.Event at 0x7f1cf48fb110>,
#    <pandda.analyse.events.Event at 0x7f1ceac6c250>]),
#  'PDK2_x0574': (0, [], []),
#  'PDK2_x0620': (0, [], []),
#  'PDK2_x0621': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf79e6ba8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf5453680>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf54530a8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf3a299f0>)],
#   [<pandda.analyse.events.Event at 0x7f1cf28db250>,
#    <pandda.analyse.events.Event at 0x7f1cf28db810>]),
#  'PDK2_x0644': (0, [], []),
#  'PDK2_x0645': (0, [], []),
#  'PDK2_x0695': (4,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871c680>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c7e0>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871cc00>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c470>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871c310>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c1b0>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871c050>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705f70>)],
#   [<pandda.analyse.events.Event at 0x7f1cf0ae6c50>,
#    <pandda.analyse.events.Event at 0x7f1cf5bb4090>,
#    <pandda.analyse.events.Event at 0x7f1cf68f9510>,
#    <pandda.analyse.events.Event at 0x7f1cf68f9350>]),
#  'PDK2_x0710': (13,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf178fc00>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf9286ec0>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf9286680>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce87054c8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705208>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce87052b8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705418>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705368>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705628>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce87056d8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705788>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705838>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce87058e8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705998>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705a48>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705af8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705ba8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705c58>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705d08>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705db8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705e68>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705f18>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce8705fc8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c0a8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871c158>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871c208>)],
#   [<pandda.analyse.events.Event at 0x7f1cf66f51d0>,
#    <pandda.analyse.events.Event at 0x7f1cea026e90>,
#    <pandda.analyse.events.Event at 0x7f1cea01ef90>,
#    <pandda.analyse.events.Event at 0x7f1cf28db890>,
#    <pandda.analyse.events.Event at 0x7f1cf0ae6f50>,
#    <pandda.analyse.events.Event at 0x7f1cf7a5f950>,
#    <pandda.analyse.events.Event at 0x7f1cf66ce7d0>,
#    <pandda.analyse.events.Event at 0x7f1cf16de1d0>,
#    <pandda.analyse.events.Event at 0x7f1cf16de810>,
#    <pandda.analyse.events.Event at 0x7f1cf16de990>,
#    <pandda.analyse.events.Event at 0x7f1cf16dec10>,
#    <pandda.analyse.events.Event at 0x7f1cf16de090>,
#    <pandda.analyse.events.Event at 0x7f1cf16dea10>]),
#  'PDK2_x0712': (0, [], []),
#  'PDK2_x0736': (0, [], []),
#  'PDK2_x0739': (0, [], []),
#  'PDK2_x0760': (0, [], []),
#  'PDK2_x0802': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871cec0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce871cd60>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1ce871ce10>,
#     <scitbx_array_family_flex_ext.double at 0x7f1ce8705d60>)],
#   [<pandda.analyse.events.Event at 0x7f1cf16def50>,
#    <pandda.analyse.events.Event at 0x7f1cf28dbd10>]),
#  'PDK2_x0808': (0, [], []),
#  'PDK2_x0812': (3,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf48cd2b8>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf5186af8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf36e5310>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf36e50a8>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf4035b50>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf4208470>)],
#   [<pandda.analyse.events.Event at 0x7f1ce9b6f850>,
#    <pandda.analyse.events.Event at 0x7f1ce7aea710>,
#    <pandda.analyse.events.Event at 0x7f1cf3734d50>]),
#  'PDK2_x0815': (0, [], []),
#  'PDK2_x0817': (2,
#   [(<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf36e5998>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf82f1260>),
#    (<scitbx_array_family_flex_ext.vec3_double at 0x7f1cf82f1cb0>,
#     <scitbx_array_family_flex_ext.double at 0x7f1cf82f1e10>)],
#   [<pandda.analyse.events.Event at 0x7f1ce9b62290>,
#    <pandda.analyse.events.Event at 0x7f1cf3af8ad0>]),
#  'PDK2_x0819': (0, [], []),
#  'PDK2_x0828': (0, [], []),
#  'PDK2_x0832': (0, [], []),
#  'PDK2_x0839': (0, [], []),
#  'PDK2_x0848': (0, [], []),
#  'PDK2_x0849': (0, [], []),
#  'PDK2_x0861': (0, [], []),
#  'PDK2_x0865': (0, [], []),
#  'PDK2_x0883': (0, [], []),
#  'PDK2_x0891': (0, [], [])}

# %%
# events_delayed = dask.delayed(dict)([(dtag, events[dtag]) for dtag in dask_dtags])

# %%
# %%time
# events_persisted_future = events_delayed.persist()

# %%
# get_persisted(events_persisted)

# %%
# events_persisted_future.compute()

# %%
# bdcs_delayed = dask.delayed(dict)([(dtag, bdcs[dtag]) for dtag in dask_dtags])

# %%
# %%time
# bdcs_persisted_future = bdcs_delayed.persist()

# %%
# bdcs_persisted_future.compute()

# %%
# map_maker, tree, map_loader, truncated_dataset, ref_map, events, bdcs, grid
# Criticise each indiidual dataset (generate statistics, event map and event table)
event_maps = {}
for dtag in dask_dtags:
    
#     event_maps[dtag] = delayed(make_event_map)(pandda_config.map_maker, 
#                                                tree, 
#                                                pandda_config.map_loader, 
#                                                truncated_datasets[dtag], 
#                                                shell_ref_map, 
#                                                events[dtag], 
#                                                bdcs[dtag], 
#                                                grid,
#                                                shell_fit_model_scattered)
    event_maps[dtag] = {}
    for event_id, bdc in bdcs_computed[dtag].items():
        event_maps[dtag][event_id] = delayed(make_event_map)(make_map,
                                                   tree,
                                                   xmaps_scattered_dict[dtag], 
                                                   truncated_datasets[dtag], 
                                                   shell_ref_map, 
                                                   (events_computed[dtag][1][event_id[1]-1],
                                                       events_computed[dtag][2][event_id[1]-1]),
                                                   bdc,
                                                  shell_fit_model_scattered, 
                                                   grid_scattered)
    #self, sample_loader, truncated_dataset, ref_map, events, bdcs, dataset_path
    # xmap, truncated_dataset, ref_map, events, bdcs, dataset_path, statistical_model, grid

# %%
# %%time
# event_maps_persisted_futures = client.persist([[event_maps[dtag][event_id] for event_id, bdc in bdcs] for dtag in dask_dtags])
event_maps_persisted_futures = {}
for dtag in dask_dtags:
    event_maps_persisted_futures[dtag] = {}
    for event_id, bdc in bdcs_computed[dtag].items():
        event_maps_persisted_futures[dtag][event_id] = client.persist(event_maps[dtag][event_id])
# get() | lambda name: put("tintin") | lambda: unit(hello name) | liftList |

# %%
pandda_config.map_maker

# %%
# %%time
# map_maker, tree, map_loader, truncated_dataset, ref_map, events, bdcs, grid, statistical_model
# event_maps_computed = {dtag: {event_id: client.compute(event_maps_persisted_futures[i]).result() 
#                   for i, dtag 
#                   in enumerate(dask_dtags)}
event_maps_computed = {}
for dtag in dask_dtags:
    event_maps_computed[dtag] = {}
    for event_id, bdc in bdcs_computed[dtag].items():
        event_maps_computed[dtag][event_id] = client.compute(event_maps[dtag][event_id]).result()

# %%
event_maps_computed

# %%
shell_maps = delayed(make_shell_maps)(map_maker, tree, name, reference, shell_ref_map)

# %%
shell_maps_persisted_futures = client.persist(shell_maps)
shell_maps_computed = shell_maps_persisted_futures.result()

# %% [markdown]
# # Make event table

# %%
event_table = delayed(make_event_table)(event_table_maker, 
                                        tree, 
                                        name, 
                                        d, 
                                        events_computed
                                       )

# %%
event_table_persisted_future = client.persist(event_table)
event_table_computed = event_table_persisted_future.result()

# %%
# # Join the event tables for each dataset to get a shell table
# shell_event_table = delayed(criticise_all)(shell_fit_model,
#                                                 [event_tables[dtag] for dtag in dask_dtags])

# %%
# %%time
# event_maps_delayed = dask.delayed(dict)([(dtag, event_maps[dtag]) for dtag in dask_dtags])
# event_maps_computed = event_maps_delayed.compute()

# %%
# %%time
# shell_maps_computed = shell_maps.compute()

# %%
# %%time
# shell_event_table.compute()

# %%
# def shell(idx, ds):
    
#     dsk = {}
#     # ###############################################
#     # Get resolution
#     # ###############################################
#     resolutions_test = max([dts.data.summary.high_res for dtag, dts
#                                 in d.partition_datasets("test").items()])
#     resolutions_train = max([dts.data.summary.high_res for dtag, dts
#                                  in d.partition_datasets("train").items()])
#     max_res = max(resolutions_test, resolutions_train)
    
    
#     # ###############################################
#     # Instantiate sheel variable names
#     # ###############################################
    
#     name = str(idx)
#     shell_sample_loader = "{}_sample_loader".format(name)
#     shell_ref_map = "{}_ref_map".format(name)
#     shell_loaded_model = "{}_loaded_model".format(name)
#     shell_max_res = "{}_max_res".format(name)
#     shell_fit_model = "{}_fit_model".format(name)
#     shell_event_table = "{}_event_table".format(name)
#     shell_reference = "{}_reference".format(name)
#     map_loader = "map_loader"
#     shell_datasets = "{}_truncated_datasets".format(name)
    
#     # Dataset names
    
#     dtags = set(d.partition_datasets("test").keys()
#                     + d.partition_datasets("train").keys()
#                     )
    
#     dask_dtags = {"{}".format(dtag.replace("-", "_")): dtag
#                  for dtag
#                  in dtags}
#     train_dtags = [dtag 
#                    for dtag 
#                    in dask_dtags
#                    if (dask_dtags[dtag] in d.partition_datasets("train").keys())]
#     test_dtags = [dtag 
#                        for dtag 
#                        in dask_dtags
#                        if (dask_dtags[dtag] in d.partition_datasets("test").keys())]   
#     print(test_dtags)
#     print(train_dtags)
    
#     truncated_datasets = {dtag: "{}_{}_truncated_dataset".format(name, dtag) for dtag in dask_dtags}
#     xmaps = {dtag: "{}_{}_xmap".format(name, dtag) for dtag in dask_dtags}
#     zmaps = {dtag: "{}_{}_zmap".format(name, dtag) for dtag in dask_dtags}
#     clusters = {dtag: "{}_{}_clusters".format(name, dtag) for dtag in dask_dtags}
#     events = {dtag: "{}_{}_events".format(name, dtag) for dtag in dask_dtags}
#     bdcs = {dtag: "{}_{}_bdcs".format(name, dtag) for dtag in dask_dtags}
#     event_tables = {dtag: "{}_{}_event_table".format(name, dtag) for dtag in dask_dtags}

#     # ###############################################
#     # Truncate datasets
#     # ###############################################
#     # TODO: move to imports section
 
#     truncated_reference, truncated_datasets_local = PanddaDiffractionDataTruncater()(d.datasets,
#                                                                                reference)
    
#     # ###############################################
#     # Load computed variables into dask
#     # ###############################################
    
#     # Load shell sample laoder
#     dsk[shell_sample_loader] = (lambda sl, g, r: sl.instantiate(g, r),
#                                 "sample_loader",
#                                 "grid",
#                                 "reference")
    
#     dsk[shell_datasets] = TruncatedDatasets(truncated_datasets_local)
    
#     for ddtag, dtag in dask_dtags.items():
#         print("{} : {}".format(truncated_datasets[ddtag], truncated_datasets_local[dtag]))
#         dsk[truncated_datasets[ddtag]] = truncated_datasets_local[dtag]
        
#     # Add truncated reference
#     dsk[shell_reference] = truncated_reference
    
#     # record max res of shell datasets
#     dsk[shell_max_res] = max_res
    
#     # ###############################################
#     # Generate maps
#     # ###############################################
    
#     # Generate reference map for shell
#     dsk[shell_ref_map] = (get_reference_map,
#                           "reference_map_getter", 
#                           "reference", 
#                           shell_max_res, 
#                           "grid")
#     # Load maps
#     for dtag in dask_dtags:
#         dsk[xmaps[dtag]] = (load_sample,
#                             map_loader, 
#                             truncated_datasets[dtag],
#                             "grid",
#                             shell_ref_map,
#                             shell_max_res)
    
#     # ###############################################
#     # Fit statistical model to trianing sets
#     # ###############################################
#     dsk[shell_fit_model] = (fit,
#                            "statistical_model", 
#                              [xmaps[dtag] for dtag in train_dtags], 
#                              [xmaps[dtag] for dtag in test_dtags]
#                           )
    
# #     # ###############################################
# #     # Find events
# #     # ###############################################
# #     for dtag in dask_dtags:
# #         # Get z maps by evaluating model on maps
# #         dsk[zmaps[dtag]]  = (evaluate,
# #                                                    shell_fit_model,
# #                                                    xmaps[dtag]
# #                                                   )

# #         # Cluster outlying points in z maps
# #         dsk[clusters[dtag]]  = (cluster,
# #                                                    shell_fit_model,
# #                                                    xmaps[dtag],
# #                                                    truncated_datasets[dtag],
# #                                                    shell_ref_map
# #                                                   )
        
        
# #         # Find events by filtering the clusters
# #         dsk[events[dtag]]  = (filter_clusters,
# #                                                    shell_fit_model,
# #                                                    xmaps[dtag],
# #                                                    truncated_datasets[dtag],
# #                                                    shell_ref_map
# #                                                   )
        
# #         # Calculate background correction factors
# #         dsk[bdcs[dtag]]  = (estimate_bdcs,
# #                                                    shell_fit_model,
# #                                                    xmaps[dtag],
# #                                                    truncated_datasets[dtag],
# #                                                    shell_ref_map
# #                                                   )
        
    
# #     # Criticise each indiidual dataset (generate statistics, event map and event table)
# #     for dtag in dask_dtags:
# #         dsk[event_tables[dtag]] = (criticise,
# #                                    shell_fit_model,
# #                                    truncated_datasets[dtag],
# #                                    events[dtag]
# #                                   )
    
# #     # Join the event tables for each dataset to get a shell table
# #     dsk[shell_event_table] = (criticise_all,
# #                             shell_fit_model,
# #                             [event_tables[dtag] for dtag in dask_dtags])

#     return dsk

# %%
# loop over model blocks
for idx, d in ds:
    
    dic = shell(idx, d)
    
    dsk.update(dic)
    
    break

# %%
print("##################################################")
print("Reference\n")
print("{}: {}".format('reference', dsk["reference"]))

print("##################################################")
print("Reference\n")
print("{}: {}".format('grid', dsk["grid"]))

print("##################################################")
print("Reference\n")
print("{}: {}".format('0_max_res', dsk["0_max_res"]))

print("##################################################")
print("sample loader\n")
print("{}: {}".format('0_sample_loader', dsk['0_sample_loader']))

print("##################################################")
print("map loader\n")
print("{}: {}".format('map_loader', dsk['map_loader']))

print("##################################################")
print("Truncated dataset\n")
print("{}: {}".format('0_PDK2_x0384_truncated_dataset', dsk['0_PDK2_x0384_truncated_dataset']))

print("##################################################")
print("Reference map\n")
print("{}: {}".format('0_ref_map', dsk["0_ref_map"]))

print("##################################################")
print("xmap\n")
print("{}: {}".format("0_PDK2_x0384_xmap", dsk["0_PDK2_x0407_xmap"]))

print("##################################################")
print("fit model\n")
print("{}: {}".format("0_fit_model", dsk["0_fit_model"]))

# print("##################################################")
# print("zmaps\n")
# print("{}: {}".format("0_PDK2_x0384_zmap", dsk["0_PDK2_x0384_zmap"]))


# print("##################################################")
# print("Cluster\n")
# print("{}: {}".format("0_PDK2_x0384_cluster", dsk["0_PDK2_x0384_events"]))

# print("##################################################")
# print("Events\n")
# print("{}: {}".format("0_PDK2_x0384_events", dsk["0_PDK2_x0384_events"]))

# print("##################################################")
# print("Event table\n")
# print("0_PDK2_x0384_event_table: {}".format(dsk["0_PDK2_x0384_event_table"]))

# print("##################################################")
# print("Shel event table\n")
# print("0_event_table: {}".format(dsk["0_event_table"]))

# %%
# dsk["0_truncated_datasets"]

# %%
# client.get(dsk, "0_truncated_datasets")

# %%
# client.get(dsk, "0_PDK2_x0407_truncated_dataset")

# %%
# client.get(dsk, "0_ref_map")

# %%
# client.get(dsk, "0_max_res")

# %%
# client.get(dsk, "map_loader")

# %%
# client.get(dsk, "0_PDK2_x0407_xmap")

# %%
# client.get(dsk, "statistical_model")

# %%
# client.get(dsk, "grid")

# %%
client.get(dsk, "0_fit_model")

# %%
client.get(dsk, "0_PDK2_x0384_zmap")

# %%
client.get(dsk, "0_PDK2_x0384_cluster")

# %%
client.get(dsk, "0_PDK2_x0384_events")

# %%
client.get(dsk, "0_PDK2_x0384_event_table")

# %%
client.close()

# %%
# dsk["model_loaded"] = model_loaded

# %%
dtags = set(model_loaded.dataset.partition_datasets("test").keys()
                    + model_loaded.dataset.partition_datasets("train").keys()
                    )

# %%
resolutions_test = max([d.data.summary.high_res for dtag, d
                                in model_loaded.dataset.partition_datasets("test").items()])
resolutions_train = max([d.data.summary.high_res for dtag, d
                                 in model_loaded.dataset.partition_datasets("train").items()])
max_res = max(resolutions_test, resolutions_train)

# %%
sample_loader = model_loaded.dataset.sample_loader

# %%
# sample_loaders = {dtag: lambda d: sample_loader.get_sample(res, d)
#                           for dtag
#                           in dtags}

# %%
for dtag in dtags:
    dsk[dtag] = (sample_loader.get_sample, max_res, model_loaded.dataset.datasets[dtag])

# %%
dsk["params"] = (model_loaded.statistical_model.fit, 
                 [dtag for dtag, d in model_loaded.dataset.partition_datasets("train").items()], 
                 [dtag for dtag, d in model_loaded.dataset.partition_datasets("test").items()])

# %%
dsk

# %%
params = client.get(dsk, "params")

# %%
# Load models over nodes
model_fit = client.submit(fit, model_loaded)

# %%
model_fit.result()

# %%
# Ask models to process
model_evaluated = evaluate(model_fit)

# %%
model_evaluated.result()

# %%
# Ask models to criticise
event_tables = criticise(models_evaluated)

# %%
client.reset()

# %%
client.restart()

# %%
client.close()

# %% [markdown]
# # Fit, evaluate, Criticise - All datasets, Dask distributed

# %% [markdown]
# ## TESTING

# %%
cluster = SGECluster(queue="medium.q",
                     cores=1,
                     processes=1,
                           memory="64GB",
                           resourcce_spec="m_mem_free=64G",
                    python="/dls/science/groups/i04-1/conor_dev/ccp4/build/bin/cctbx.python")

# %%
cluster.scale(3)

# %%
time.sleep(15)

# %%
cluster = LocalCluster(n_workers=2, threads_per_worker=1)

# %%
client = Client(cluster)

# %%
client

# %%
# Main Loop
dataloader = DefaultPanDDADataloader(min_train_datasets=60, 
                                     max_test_datasets=60)

# %%
ds = [(idx, d) for idx, d in dataloader(dataset)]

# %%
# Get base distributed model
pandda_event_model_distributed = PanDDAEventModelDistributed(pandda_config.statistical_model,
                                      pandda_config.clusterer,
                                      pandda_config.event_finder,
                                        dataset=dataset,
                                      bdc_calculator=pandda_config.bdc_calculator,
                                      statistics=[],
                                      map_maker=pandda_config.map_maker, 
                                      event_table_maker=pandda_config.event_table_maker,
                                      cpus=config["args"]["cpus"],
                                      tree=tree)

# %%
pandda_event_model_distributed.instantiate(reference,
                                           tree)

# %%
# Instantiate models
models = [pandda_event_model_distributed.clone(dataset=d, 
                                   name=idx)
         for idx, d
         in ds]

# %%
# models

# %%
# # Load model moponents
# models_loaded = client.map(load,
#                     models,
#                           pure=False)

# %%
# models_loaded

# %%
# # Load models over nodes
# models_fit = client.map(fit, 
#                            models_loaded,
#                        pure=False)

# %%
# models_fit

# %%
# # Ask models to process
# models_evaluated = client.map(evaluate, 
#                               models_fit,
#                              pure=False)

# %%
# models_evaluated

# %%
# # Ask models to criticise
# event_tables = client.map(criticise, 
#                                models_evaluated, 
#                                pure=False)

# %%
# event_tables

# %%
# event_tables_results =[e.result() for e in event_tables]

# %%
dsk = {}
for i, model in enumerate(models):
    dsk["load_{}".format(i)] = (load, model)
    dsk["fit_{}".format(i)] = (fit, "load_{}".format(i))
    dsk["evaluate_{}".format(i)] = (evaluate, "fit_{}".format(i))
    dsk["criticise_{}".format(i)] = (criticise, "evaluate_{}".format(i))

# %%
dsk

# %%
dsk_combined, deps = dask.optimization.fuse(dsk)

# %%
client.get(dsk_combined, ["criticise_{}".format(i)
                          for i, model
                          in enumerate(models)])

# %%
client.close()

# %%
# Visualise tasks

# %%
# Ask models for events
event_tables = event_tables.results()

# %%
with ProcessModelSeriel() as P:            

    for dataset in dataloader(dataset):

        P(pandda_event_model(dataset))
        # call with self as model: model.fit(); model.evaluate(); model.criticise()
            # Seriel: run immediately
            # Qsub: pick model

    # exit: 
        # Seriel: just go on
        # qsub: wait for the jobs to complete

# %%
for dataset in dataloader(dataset):
    
    with pandda_event_model(dataset) as model:

        # Fit model
        print("Fitting model")
        model.fit()  # Fit the statistical model

        # Evaluate model
        model.evaluate_parallel()  # Evaluate the fitted model on maps, fidning events

        # Criticise Model
        model.criticise() # Stores statistics from model fitting and evaluation

# %% [markdown]
# # Criticise Run

# %% [markdown]
# ## TESTING

# %%
# Criticise Model
pandda_statistics = PanDDARunStatistics(dataset, model)  # Generates statistics from dataset and model
PanDDARunGraphs(pandda_statistics)  # Produces a set of graphs of statistics
pandda_html = PanDDARunHTML(pandda_statistics)  # Produces a HTML from Statistics
PanDDARunLog()  # Produces a log of data processing from dataset, model, graphs and HTML

# %%
with processor as P:            

    for dataset in dataloader(dataset):

        P(pandda_event_model(dataset))
        # call with self as model: model.fit(); model.evaluate(); model.criticise()
            # Seriel: run immediately
            # Qsub: pick model

    # exit: 
        # Seriel: just go on
        # qsub: wait for the jobs to complete

# %%
class PanDDARunStatistics:
    
    def __init__(dataset, model):
        
        self.statistics = [...]
        
        for statistic in self.statistic:
            try:
                statistic.calculate()
                self.trace[statistic.name] = statistic.log()

            except Exeption as e:
                self.trace[statistic.name] = "{}".format(e)

# %%
class OutputNativeMaps:
    
    def calculate(samples):
        
        
        
    def log():
